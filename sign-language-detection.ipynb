# %%
# ==== Cell 1: Environment ====
# !pip install --no-cache-dir --quiet \
  "numpy==1.26.4" \
  "opencv-python-headless==4.10.0.84" \
  "mediapipe==0.10.14" \
  "tensorflow==2.18.0" \
  "protobuf==4.25.3" \
  "scipy==1.11.4"

import os, sys, json, glob, math, time
import numpy as np
import cv2
import tensorflow as tf

print("✅ Ready.")
print("Python:", sys.version)
print("NumPy:", np.__version__, "| TF:", tf.__version__, "| OpenCV:", cv2.__version__)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 293.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 210.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 211.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 288.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 261.4 MB/s eta 0:00:00a 0:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 4.25.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# 2025-11-28 09:54:43.318821: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764323683.539442      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764323683.598130      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ Ready.
# Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# NumPy: 1.26.4 | TF: 2.18.0 | OpenCV: 4.10.0

# %%
# ==== Cell 2: Safe Mediapipe import (Py 3.11) ====
import types

# Patch nhẹ để Mediapipe không lôi 'tasks.audio' (hay lỗi 'framework/python/gpu')
import sys as _sys
_sys.modules.setdefault("mediapipe.tasks", types.SimpleNamespace(python=types.SimpleNamespace(audio=types.SimpleNamespace())))
_sys.modules.setdefault("mediapipe.tasks.python", types.SimpleNamespace(audio=types.SimpleNamespace()))
_sys.modules.setdefault("mediapipe.tasks.python.audio", types.SimpleNamespace())

# Import
import mediapipe as mp
mp_holistic = mp.solutions.holistic
mp_drawing  = mp.solutions.drawing_utils

print("✅ Mediapipe OK:", mp.__version__)
# Out:
# ✅ Mediapipe OK: 0.10.14

# %%
import mediapipe as mp
import google.protobuf
print(mp.__version__)           # nên >=0.10.21
print(google.protobuf.__version__)  # 4.25.8
# Out:
# 0.10.14
# 4.25.3

# %%
# ==== Cell 3: Paths & labels (REPLACE) ====
import os, json, glob
 #tạo thư mục làm việc
BASE_DIR   = "/kaggle/working"
SAVE_DIR   = os.path.join(BASE_DIR, "sign_language_detection")
PRED_DIR   = os.path.join(BASE_DIR, "pred_videos")
os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)

#  Dùng đúng dataset 
DATA_DIR = "/kaggle/input/dataset/SignLanguageVideo_VipCut"
assert os.path.isdir(DATA_DIR), f" Không thấy DATA_DIR: {DATA_DIR}"

# Khóa thứ tự nhãn theo TÊN THƯ MỤC
actions = sorted([d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))])
assert len(actions) >= 2, " Cần >=2 thư mục nhãn con trong DATA_DIR"
with open(os.path.join(SAVE_DIR, "labels.json"), "w", encoding="utf-8") as f:
    json.dump(actions, f, ensure_ascii=False, indent=2)

print("DATA_DIR:", DATA_DIR)
print(" LABELS (đã khóa):", actions)

# (tuỳ chọn) In thống kê nhanh mỗi lớp
counts = {lbl: len(glob.glob(os.path.join(DATA_DIR, lbl, "*.mp4"))) for lbl in actions}
print("📊 Per-class counts:", counts, "| Tổng:", sum(counts.values()))
# Out:
# DATA_DIR: /kaggle/input/dataset/SignLanguageVideo_VipCut
#  LABELS (đã khóa): ['Again', 'BathRoom', 'Finish', 'Hello', 'Help', 'No', 'Please', 'SeeYouLater', 'ThankYou', 'Yes']
# 📊 Per-class counts: {'Again': 90, 'BathRoom': 93, 'Finish': 90, 'Hello': 92, 'Help': 90, 'No': 90, 'Please': 90, 'SeeYouLater': 90, 'ThankYou': 90, 'Yes': 90} | Tổng: 905

# %%
# ==== Tạo danh sách video + label ====
samples = []
for label in actions:
    vids = glob.glob(os.path.join(DATA_DIR, label, "*.mp4"))
    samples += [(v, label) for v in vids]

print("Total videos:", len(samples))
# Out:
# Total videos: 905

# %%
# =========================
# Hàm trích 134 keypoints (UpperBody + Hands rút gọn)
# =========================
import numpy as np

def extract_keypoints_from_frame(results):
    """
    Trích xuất keypoints rút gọn:
    - UpperBody: 4 điểm (11,12,23,24) x 2 (x,y) = 8
    - Hands: left + right hand = 21*3 + 21*3 = 126
    Tổng = 8 + 126 = 134
    """
    # UpperBody
    upperbody_idx = [11, 12, 23, 24]  # Pose landmarks
    upperbody = np.zeros((4,2), dtype=np.float32)
    if results.pose_landmarks:
        for i, idx in enumerate(upperbody_idx):
            lm = results.pose_landmarks.landmark[idx]
            upperbody[i] = [lm.x, lm.y]

    # Hands
    lh = np.zeros((21,3), dtype=np.float32)
    rh = np.zeros((21,3), dtype=np.float32)
    if results.left_hand_landmarks:
        for i, lm in enumerate(results.left_hand_landmarks.landmark):
            lh[i] = [lm.x, lm.y, lm.z]
    if results.right_hand_landmarks:
        for i, lm in enumerate(results.right_hand_landmarks.landmark):
            rh[i] = [lm.x, lm.y, lm.z]

    return np.concatenate([upperbody.flatten(), lh.flatten(), rh.flatten()])

# %%
# ==== Cell 4: Keypoint extraction & video reading ====
import numpy as np
import cv2

SEQLEN = 48
RAW_FEAT_DIM = 134  # UpperBody + Hands rút gọn

def read_video_keypoints(vpath, seqlen=SEQLEN, step=1, head_sec=0.0, tail_sec=0.0):
    """
    Đọc video, trích xuất keypoints 134 chiều và trả về sliding windows (N, SEQLEN, RAW_FEAT_DIM)
    """
    from mediapipe import solutions as mp_solutions

    cap = cv2.VideoCapture(vpath)
    if not cap.isOpened():
        print("Cannot open:", vpath)
        return []

    fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT) or 0)
    start_f = int(round(fps * head_sec))
    end_f   = total - int(round(fps * tail_sec)) if total > 0 else 10**9

    if start_f > 0:
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_f)

    frames = []
    with mp_solutions.holistic.Holistic(
        static_image_mode=False,
        model_complexity=1,
        enable_segmentation=False
    ) as hol:
        idx = start_f
        while True:
            ok, frame = cap.read()
            if not ok or idx >= end_f:
                break
            idx += 1
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            res = hol.process(frame)
            frames.append(extract_keypoints_from_frame(res))

    cap.release()
    arr = np.array(frames, dtype=np.float32)
    if len(arr) < seqlen:
        return []

    seqs = []
    for i in range(0, len(arr) - seqlen + 1, step):
        seqs.append(arr[i:i+seqlen])
    return seqs

# %%
# ==== Cell 4b: Build dataset ====
import os, glob
import numpy as np
import tensorflow as tf
from concurrent.futures import ThreadPoolExecutor, as_completed
from sklearn.model_selection import train_test_split
from tqdm import tqdm

SEQLEN = 48
RAW_FEAT_DIM = 134

def sequence_upperbody_hand_normalize(seq):
    """
    Chuẩn hóa: dịch chuyển trung tâm và scale dựa trên vai/hips.
    seq: (SEQLEN, RAW_FEAT_DIM)
    """
    s = seq.copy()
    # UpperBody: 4 điểm x 2 (x,y)
    upper = s[:, :8]

    # Hands: 21*3 x2 = 126
    lh = s[:, 8:8+63].reshape(-1,21,3)
    rh = s[:, 8+63:].reshape(-1,21,3)

    # Tính trung tâm vai/hips (dùng UpperBody)
    ls = upper[:,0:2]   # 11
    rs = upper[:,2:4]   # 12
    lh_c = upper[:,4:6] # 23
    rh_c = upper[:,6:8] # 24
    shoulders = (ls+rs)/2
    hips      = (lh_c+rh_c)/2
    center = (shoulders+hips)/2
    scale = np.linalg.norm(shoulders-hips, axis=1, keepdims=True) + 1e-6

    # Chuẩn hóa hand
    lh[:,:,0:2] = (lh[:,:,0:2] - center[:,None,:])/scale[:,None,:]
    rh[:,:,0:2] = (rh[:,:,0:2] - center[:,None,:])/scale[:,None,:]

    lh_out = lh.reshape(-1,63)
    rh_out = rh.reshape(-1,63)

    return np.concatenate([upper, lh_out, rh_out], axis=1).astype(np.float32)


def process_single_video(vpath, label, stride, actions):
    seqs = read_video_keypoints(vpath, seqlen=SEQLEN, step=stride, head_sec=0.3)
    seqs = [sequence_upperbody_hand_normalize(s) for s in seqs]

    X_v, y_v = [], []
    onehot = tf.keras.utils.to_categorical(actions.index(label), num_classes=len(actions))
    for s in seqs:
        if s.shape == (SEQLEN, RAW_FEAT_DIM):
            X_v.append(s)
            y_v.append(onehot)
    return X_v, y_v, {label: len(X_v)}


def build_split_parallel(samples, stride=8, max_workers=8):
    X_list, y_list, counts = [], [], {}
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        futs = {ex.submit(process_single_video, v, l, stride, actions):(v,l) for v,l in samples}
        for fut in tqdm(as_completed(futs), total=len(futs)):
            X_v, y_v, c = fut.result()
            X_list += X_v
            y_list += y_v
            for k,v in c.items():
                counts[k] = counts.get(k,0) + v
    return np.array(X_list), np.array(y_list), counts


# ===== Prepare samples =====
samples = []
for label in actions:
    vids = glob.glob(os.path.join(DATA_DIR, label, "*.mp4"))
    for v in vids:
        samples.append((v,label))

train_samples, val_samples = train_test_split(samples, test_size=0.2, random_state=42)

stride = 8
X_train, y_train, counts_train = build_split_parallel(train_samples, stride=stride)
X_val, y_val, counts_val = build_split_parallel(val_samples, stride=stride)

print("✅ X_train:", X_train.shape, "| y_train:", y_train.shape)
print("✅ X_val:", X_val.shape, "| y_val:", y_val.shape)
print("📊 Train counts:", counts_train)
print("📊 Val counts:", counts_val)
print("Raw feature dim:", RAW_FEAT_DIM, "| Seq len:", SEQLEN)
# Out:
#   0%|          | 0/724 [00:00<?, ?it/s]INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1764323702.459697     138 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.478549     133 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.481168     134 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.521287     138 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.523804     141 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.525981     139 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.538788     138 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.589582     138 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.633690     139 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.639994     141 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.651449     133 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.653349     132 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.651448     136 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.658897     131 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.663100     135 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.660949     137 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.660981     136 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.661126     132 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.677787     150 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.697206     135 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.715771     153 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.723902     131 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.777561     130 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.788392     137 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.806861     150 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.808539     149 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.809590     151 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.820283     153 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.820501     150 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.822256     155 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.823512     155 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.842013     153 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.846591     132 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.856791     136 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.860459     150 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.908720     153 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.943752     149 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.966536     151 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.982398     156 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323702.990459     155 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /usr/local/lib/python3.11/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# W0000 00:00:1764323704.069063     167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.132380     172 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.152057     167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.155543     167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.156726     165 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.158131     166 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.222320     166 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.296593     165 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.326188     167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.347220     172 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.352682     171 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.353555     170 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.360194     172 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.436352     171 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.443955     170 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.445048     172 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323704.934669     177 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.141903     180 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.146296     178 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.149294     178 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.154315     179 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.206538     179 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.297576     178 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323705.314544     177 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 2/724 [00:34<2:52:04, 14.30s/it]W0000 00:00:1764323737.020287     186 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.159379     186 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.160987     185 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.161033     186 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.165107     188 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.198592     186 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.210084     188 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.343768     185 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.634264     193 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.850932     193 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.858858     194 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.863982     195 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.871876     196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.928289     196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323737.990710     195 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323738.029673     194 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 4/724 [00:42<1:25:51,  7.15s/it]W0000 00:00:1764323744.403842     201 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.534867     201 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.536729     203 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.537938     204 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.551238     201 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.577492     201 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 5/724 [00:42<56:12,  4.69s/it]  W0000 00:00:1764323744.710258     203 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323744.753934     204 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.502155     209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.671691     209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.673767     209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.673853     210 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.683158     212 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.729877     212 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.821882     209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323745.843109     210 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 6/724 [00:44<44:16,  3.70s/it]W0000 00:00:1764323746.653549     217 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.750364     220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.754272     220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.760881     220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.763972     219 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.789868     219 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.815118     218 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323746.841771     220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 7/724 [00:45<31:51,  2.67s/it]W0000 00:00:1764323747.517951     225 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.620876     225 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.622478     227 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.622645     228 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.625844     225 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.644064     225 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.730431     227 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323747.802804     228 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.353631     233 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.589917     233 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.591817     233 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.598178     234 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.598706     233 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.668316     234 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.712882     233 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323748.746706     235 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 8/724 [00:47<31:02,  2.60s/it]W0000 00:00:1764323751.307005     243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.432315     243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.436839     241 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.441062     244 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.442514     243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.465749     244 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.491505     241 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323751.562978     243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 9/724 [01:01<1:13:42,  6.19s/it]W0000 00:00:1764323764.810162     249 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.037865     249 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.039916     249 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.040773     251 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.042123     250 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.070676     250 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.142112     251 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323765.148068     249 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|▏         | 10/724 [01:05<1:03:32,  5.34s/it]W0000 00:00:1764323768.065966     259 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.231896     258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.233728     258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.236931     257 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.242871     258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.298364     257 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.351019     260 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323768.417252     258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 11/724 [01:16<1:23:57,  7.07s/it]W0000 00:00:1764323778.980642     267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.152279     265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.154536     265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.164844     267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.155856     266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.200013     267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.275157     265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323779.314806     266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 12/724 [01:21<1:17:53,  6.56s/it]W0000 00:00:1764323784.530461     273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.747704     273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.749427     273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.755139     276 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.764720     273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.798109     276 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.909588     274 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323784.924100     273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 14/724 [01:26<51:14,  4.33s/it]  W0000 00:00:1764323789.219680     287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.274396     287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.276240     285 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.277413     285 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.281008     288 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.335914     288 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.359402     289 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.361514     287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 15/724 [01:27<39:51,  3.37s/it]W0000 00:00:1764323789.431367     285 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.472453     290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.474062     290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.478215     292 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.493203     290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.518569     292 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.551103     291 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323789.605832     290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 16/724 [01:28<30:18,  2.57s/it]W0000 00:00:1764323790.486004     298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.637858     298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.639777     299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.647919     299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.652294     298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.699159     298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.742514     300 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323790.742638     299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.465931     305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.569221     305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.578929     306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.583106     307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.584243     305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.626629     307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.688673     306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323791.743880     305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 18/724 [01:40<46:32,  3.96s/it]W0000 00:00:1764323802.443274     314 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.534757     315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.536129     315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.537989     316 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.540360     313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.566509     316 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.579533     315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323802.682704     313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.249829     322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.451672     322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.453722     321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.457442     324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.466421     322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.502981     322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.557637     324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323803.609288     321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 19/724 [01:51<1:11:14,  6.06s/it]W0000 00:00:1764323814.453398     331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.616103     331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.618229     331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.624617     332 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.625563     331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.699604     332 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.762047     330 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323814.762484     331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 20/724 [01:56<1:05:50,  5.61s/it]W0000 00:00:1764323819.270322     340 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.541797     337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.549027     338 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.549780     339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.557334     337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.608166     339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.705928     338 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323819.711680     337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 21/724 [01:59<57:16,  4.89s/it]  W0000 00:00:1764323822.408462     345 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.553973     345 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.558736     348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.559923     347 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.561320     345 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.594398     347 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.649104     345 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323822.669495     348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 22/724 [02:01<46:53,  4.01s/it]W0000 00:00:1764323824.230372     355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.288436     355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.290777     356 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.293293     354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.302416     355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.370034     355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323824.402850     354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 23/724 [02:02<38:01,  3.25s/it]W0000 00:00:1764323824.459642     356 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.514001     361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.654694     361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.658357     362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.659587     364 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.662351     361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.693914     362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.742444     364 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323825.789057     361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   3%|▎         | 24/724 [02:04<31:50,  2.73s/it]W0000 00:00:1764323827.458692     369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.572616     369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.578618     372 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.580195     370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.590953     369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.624468     369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764323827.657783     370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
# W0000 00:00:1764328215.094149    7289 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328215.223496    7290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.450072    7299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.564642    7299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.566478    7298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.584729    7298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.597696    7299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.655472    7299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.783199    7298 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328216.789248    7300 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  91%|█████████ | 165/181 [14:09<01:16,  4.78s/it]W0000 00:00:1764328222.193061    7307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.298279    7307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.306044    7307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.307554    7306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.319183    7305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.358129    7305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.392625    7306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328222.457739    7307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  92%|█████████▏| 166/181 [14:18<01:29,  5.94s/it]W0000 00:00:1764328231.221210    7313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  92%|█████████▏| 167/181 [14:20<01:06,  4.76s/it]W0000 00:00:1764328231.347633    7313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.356992    7313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.377745    7313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.380128    7314 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.463822    7314 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.506265    7316 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328231.553085    7313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  93%|█████████▎| 168/181 [14:21<00:46,  3.57s/it]W0000 00:00:1764328232.071619    7321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.261743    7323 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.263317    7321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.263329    7324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.275371    7323 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.333809    7323 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.361306    7324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328232.370669    7321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.644537    7329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.774020    7329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.776826    7331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.777897    7330 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.781745    7329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.837670    7330 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.877231    7331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328233.958765    7329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  94%|█████████▍| 170/181 [14:24<00:26,  2.43s/it]W0000 00:00:1764328235.403717    7339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.521061    7339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.524551    7337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.528142    7338 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.538154    7339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.577811    7339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.637264    7338 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328235.646705    7337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328236.987504    7345 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.062339    7348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.064225    7346 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.068477    7346 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.075406    7348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.111236    7348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.142248    7346 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328237.190013    7347 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  94%|█████████▍| 171/181 [14:32<00:41,  4.13s/it]W0000 00:00:1764328244.609000    7354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.831634    7356 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.833678    7355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.840670    7355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.844746    7353 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.890819    7353 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.948138    7354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328244.979457    7355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  95%|█████████▌| 172/181 [14:41<00:50,  5.59s/it]W0000 00:00:1764328253.435109    7362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.598744    7362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.601531    7361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.602959    7364 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.608407    7362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.653697    7362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.740487    7364 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328253.774457    7361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  96%|█████████▌| 173/181 [14:44<00:40,  5.09s/it]W0000 00:00:1764328258.264410    7370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.414222    7370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.416182    7369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.419617    7369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.440052    7370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.476753    7370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.513924    7371 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764328258.537981    7369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 100%|██████████| 181/181 [15:09<00:00,  5.03s/it]
# ✅ X_train: (4414, 48, 134) | y_train: (4414, 10)
# ✅ X_val: (1089, 48, 134) | y_val: (1089, 10)
# 📊 Train counts: {'Again': 531, 'ThankYou': 411, 'Help': 328, 'Hello': 352, 'SeeYouLater': 512, 'Yes': 536, 'BathRoom': 594, 'Finish': 347, 'Please': 362, 'No': 441}
# 📊 Val counts: {'Again': 120, 'Finish': 97, 'No': 95, 'BathRoom': 95, 'Yes': 162, 'Help': 78, 'SeeYouLater': 75, 'Hello': 147, 'Please': 117, 'ThankYou': 103}
# Raw feature dim: 134 | Seq len: 48

# %%
# === Cell SPLIT: Tất cả video chứa 'section_' đưa vào validation ===

train_samples = []
val_samples = []

for label in actions:
    folder = os.path.join(DATA_DIR, label)
    vids = sorted(glob.glob(os.path.join(folder, "*.mp4")))

    for v in vids:
        fname = os.path.basename(v).lower()

        # Nếu tên chứa section_XX → cho vào validation
        if "section_" in fname:
            val_samples.append((v, label))
        else:
            train_samples.append((v, label))

# --- Thống kê ---
print("=== VIDEO SPLIT SUMMARY ===")
for label in actions:
    t_count = sum(1 for _, l in train_samples if l == label)
    v_count = sum(1 for _, l in val_samples if l == label)
    print(f"{label:12s} | train={t_count:3d} | val={v_count:3d}")

print("\n➡️ Sẵn sàng build dataset bằng build_split_parallel(...)")
# Out:
# === VIDEO SPLIT SUMMARY ===
# Again        | train= 70 | val= 20
# BathRoom     | train= 73 | val= 20
# Finish       | train= 70 | val= 20
# Hello        | train= 72 | val= 20
# Help         | train= 70 | val= 20
# No           | train= 70 | val= 20
# Please       | train= 70 | val= 20
# SeeYouLater  | train= 70 | val= 20
# ThankYou     | train= 70 | val= 20
# Yes          | train= 70 | val= 20
#
# ➡️ Sẵn sàng build dataset bằng build_split_parallel(...)

# %%
# ==== Cell Build & Train: 2-layer model ====
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses, callbacks

seq_len = SEQLEN      # 48
feat_dim = RAW_FEAT_DIM  # 134
num_classes = len(actions)

# --- Positional embedding ---
class LearnedPositionalEmbedding(layers.Layer):
    def __init__(self, max_len, **kwargs):
        super().__init__(**kwargs)
        self.max_len = max_len
    def build(self, input_shape):
        d_model = input_shape[-1]
        self.pos_emb = self.add_weight(
            name="pos_emb", shape=(self.max_len, d_model),
            initializer="uniform", trainable=True
        )
    def call(self, x):
        return x + self.pos_emb
    def get_config(self):
        config = super().get_config()
        config.update({"max_len": self.max_len})
        return config

# --- Attention pooling ---
class AttentionPooling(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    def build(self, input_shape):
        d = input_shape[-1]
        self.W = self.add_weight(shape=(d,1), initializer="glorot_uniform", trainable=True)
    def call(self, x):
        scores = tf.nn.softmax(tf.squeeze(tf.matmul(x,self.W),axis=-1), axis=1)
        ctx = tf.reduce_sum(x * scores[:,:,None], axis=1)
        return ctx
    def get_config(self):
        return super().get_config()

# --- Build model ---
inputs = layers.Input(shape=(seq_len, feat_dim))
x = layers.GaussianNoise(0.01)(inputs)

# 1 Conv1D layer
x = layers.Conv1D(192, 5, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

# 1 BiLSTM layer
x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
x = layers.Dropout(0.3)(x)

# Positional embedding
x = LearnedPositionalEmbedding(max_len=seq_len)(x)

# Attention pooling + Dense head
ctx = AttentionPooling()(x)
x = layers.Dense(256, activation="relu")(ctx)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)

# --- Compile ---
opt = optimizers.AdamW(learning_rate=2e-4, weight_decay=1e-4)
loss_fn = losses.CategoricalCrossentropy(label_smoothing=0.02)
top2 = tf.keras.metrics.TopKCategoricalAccuracy(k=2, name="top2")
model.compile(optimizer=opt, loss=loss_fn, metrics=["accuracy", top2])
model.summary()

# --- Callbacks ---
checkpoint = callbacks.ModelCheckpoint("best_model.keras", monitor="val_loss", save_best_only=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6)

# --- Train ---
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[checkpoint, reduce_lr]
)
# Out:
# 2025-11-28 11:11:20.769674: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 134)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 48, 134)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 48, 192)        │       128,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 192)        │           768 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 48, 192)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 48, 256)        │       328,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 48, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ learned_positional_embedding    │ (None, 48, 256)        │        12,288 │
# │ (LearnedPositionalEmbedding)    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_pooling               │ (None, 256)            │           256 │
# │ (AttentionPooling)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 539,210 (2.06 MB)
#  Trainable params: 538,826 (2.06 MB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 23s 127ms/step - accuracy: 0.6121 - loss: 1.2962 - top2: 0.7956 - val_accuracy: 0.6814 - val_loss: 1.0627 - val_top2: 0.8494 - learning_rate: 2.0000e-04
# Epoch 2/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9618 - loss: 0.2704 - top2: 0.9917 - val_accuracy: 0.8007 - val_loss: 0.7206 - val_top2: 0.8604 - learning_rate: 2.0000e-04
# Epoch 3/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9825 - loss: 0.2027 - top2: 0.9962 - val_accuracy: 0.8962 - val_loss: 0.5379 - val_top2: 0.9477 - learning_rate: 2.0000e-04
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9904 - loss: 0.1790 - top2: 0.9995 - val_accuracy: 0.8430 - val_loss: 0.5979 - val_top2: 0.9706 - learning_rate: 2.0000e-04
# Epoch 5/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9923 - loss: 0.1681 - top2: 0.9970 - val_accuracy: 0.9770 - val_loss: 0.2175 - val_top2: 0.9991 - learning_rate: 2.0000e-04
# Epoch 6/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9954 - loss: 0.1604 - top2: 0.9984 - val_accuracy: 0.9697 - val_loss: 0.2283 - val_top2: 0.9991 - learning_rate: 2.0000e-04
# Epoch 7/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9934 - loss: 0.1609 - top2: 0.9987 - val_accuracy: 0.8292 - val_loss: 0.5809 - val_top2: 0.9862 - learning_rate: 2.0000e-04
# Epoch 8/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 123ms/step - accuracy: 0.9907 - loss: 0.1661 - top2: 0.9971 - val_accuracy: 0.9899 - val_loss: 0.2138 - val_top2: 0.9945 - learning_rate: 2.0000e-04
# Epoch 9/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 124ms/step - accuracy: 0.9931 - loss: 0.1581 - top2: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.2723 - val_top2: 0.9972 - learning_rate: 2.0000e-04
# Epoch 10/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9951 - loss: 0.1540 - top2: 0.9991 - val_accuracy: 0.9660 - val_loss: 0.2362 - val_top2: 0.9972 - learning_rate: 2.0000e-04
# Epoch 11/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9972 - loss: 0.1493 - top2: 0.9999 - val_accuracy: 0.9330 - val_loss: 0.2887 - val_top2: 0.9963 - learning_rate: 2.0000e-04
# Epoch 12/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9980 - loss: 0.1454 - top2: 0.9999 - val_accuracy: 0.8953 - val_loss: 0.4204 - val_top2: 1.0000 - learning_rate: 2.0000e-04
# Epoch 13/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 126ms/step - accuracy: 0.9971 - loss: 0.1468 - top2: 0.9998 - val_accuracy: 0.8430 - val_loss: 0.5685 - val_top2: 0.9936 - learning_rate: 2.0000e-04
# Epoch 14/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9978 - loss: 0.1454 - top2: 0.9996 - val_accuracy: 0.9954 - val_loss: 0.1469 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 15/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9992 - loss: 0.1410 - top2: 0.9997 - val_accuracy: 0.8641 - val_loss: 0.5148 - val_top2: 0.9376 - learning_rate: 1.0000e-04
# Epoch 16/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9983 - loss: 0.1428 - top2: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1689 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 17/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9995 - loss: 0.1410 - top2: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.1548 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 18/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9984 - loss: 0.1424 - top2: 0.9996 - val_accuracy: 0.9734 - val_loss: 0.1963 - val_top2: 1.0000 - learning_rate: 1.0000e-04
# Epoch 19/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9996 - loss: 0.1418 - top2: 0.9999 - val_accuracy: 0.9972 - val_loss: 0.1407 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 20/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9991 - loss: 0.1407 - top2: 1.0000 - val_accuracy: 0.9890 - val_loss: 0.1705 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 21/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9981 - loss: 0.1410 - top2: 0.9998 - val_accuracy: 0.9982 - val_loss: 0.1410 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 22/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9995 - loss: 0.1389 - top2: 1.0000 - val_accuracy: 0.9871 - val_loss: 0.1655 - val_top2: 0.9982 - learning_rate: 1.0000e-04
# Epoch 23/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9980 - loss: 0.1431 - top2: 0.9989 - val_accuracy: 0.9881 - val_loss: 0.2520 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 24/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.9983 - loss: 0.1446 - top2: 0.9994 - val_accuracy: 0.9991 - val_loss: 0.1398 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 25/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - accuracy: 0.9990 - loss: 0.1402 - top2: 0.9997 - val_accuracy: 0.9780 - val_loss: 0.2077 - val_top2: 1.0000 - learning_rate: 1.0000e-04
# Epoch 26/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9989 - loss: 0.1402 - top2: 0.9993 - val_accuracy: 0.9972 - val_loss: 0.1419 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 27/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9995 - loss: 0.1391 - top2: 0.9999 - val_accuracy: 0.9982 - val_loss: 0.1407 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 28/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - accuracy: 0.9991 - loss: 0.1386 - top2: 0.9996 - val_accuracy: 0.9917 - val_loss: 0.1556 - val_top2: 1.0000 - learning_rate: 1.0000e-04
# Epoch 29/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9998 - loss: 0.1401 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1394 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 30/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 1.0000 - loss: 0.1367 - top2: 1.0000 - val_accuracy: 0.9945 - val_loss: 0.1499 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 31/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - accuracy: 0.9979 - loss: 0.1423 - top2: 0.9995 - val_accuracy: 0.9311 - val_loss: 0.3108 - val_top2: 0.9982 - learning_rate: 1.0000e-04
# Epoch 32/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 20s 120ms/step - accuracy: 0.9981 - loss: 0.1411 - top2: 0.9998 - val_accuracy: 0.9679 - val_loss: 0.2581 - val_top2: 0.9890 - learning_rate: 1.0000e-04
# Epoch 33/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - accuracy: 0.9995 - loss: 0.1386 - top2: 0.9996 - val_accuracy: 0.9963 - val_loss: 0.1422 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 34/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - accuracy: 0.9982 - loss: 0.1408 - top2: 0.9997 - val_accuracy: 0.9972 - val_loss: 0.1573 - val_top2: 0.9991 - learning_rate: 1.0000e-04
# Epoch 35/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.9992 - loss: 0.1382 - top2: 0.9993 - val_accuracy: 0.9972 - val_loss: 0.1408 - val_top2: 0.9991 - learning_rate: 5.0000e-05
# Epoch 36/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.9995 - loss: 0.1378 - top2: 0.9999 - val_accuracy: 0.9972 - val_loss: 0.1407 - val_top2: 0.9991 - learning_rate: 5.0000e-05
# Epoch 37/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 18s 133ms/step - accuracy: 1.0000 - loss: 0.1372 - top2: 1.0000 - val_accuracy: 0.9972 - val_loss: 0.1408 - val_top2: 0.9991 - learning_rate: 5.0000e-05
# Epoch 38/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9999 - loss: 0.1365 - top2: 0.9999 - val_accuracy: 0.9826 - val_loss: 0.1746 - val_top2: 0.9991 - learning_rate: 5.0000e-05
# Epoch 39/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 126ms/step - accuracy: 0.9999 - loss: 0.1364 - top2: 1.0000 - val_accuracy: 0.9936 - val_loss: 0.1492 - val_top2: 0.9991 - learning_rate: 5.0000e-05
# Epoch 40/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 126ms/step - accuracy: 0.9994 - loss: 0.1381 - top2: 0.9994 - val_accuracy: 0.9982 - val_loss: 0.1390 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 41/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9997 - loss: 0.1364 - top2: 0.9997 - val_accuracy: 0.9982 - val_loss: 0.1390 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 42/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9990 - loss: 0.1373 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1388 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 43/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9993 - loss: 0.1373 - top2: 0.9998 - val_accuracy: 0.9982 - val_loss: 0.1402 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 44/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 124ms/step - accuracy: 0.9993 - loss: 0.1381 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1390 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 45/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 124ms/step - accuracy: 0.9987 - loss: 0.1374 - top2: 0.9994 - val_accuracy: 0.9972 - val_loss: 0.1407 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 46/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 124ms/step - accuracy: 0.9992 - loss: 0.1370 - top2: 0.9993 - val_accuracy: 0.9972 - val_loss: 0.1402 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 47/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 1.0000 - loss: 0.1362 - top2: 1.0000 - val_accuracy: 0.9972 - val_loss: 0.1388 - val_top2: 0.9991 - learning_rate: 2.5000e-05
# Epoch 48/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 126ms/step - accuracy: 1.0000 - loss: 0.1355 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1381 - val_top2: 0.9991 - learning_rate: 1.2500e-05
# Epoch 49/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 1.0000 - loss: 0.1357 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1379 - val_top2: 0.9991 - learning_rate: 1.2500e-05
# Epoch 50/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - accuracy: 0.9999 - loss: 0.1360 - top2: 1.0000 - val_accuracy: 0.9982 - val_loss: 0.1387 - val_top2: 0.9991 - learning_rate: 1.2500e-05

# %%
# Lưu model cuối cùng (không chỉ best)
model.save("final_model.keras")

# %%
from tensorflow.keras.models import load_model

# --- 1. Định nghĩa lại các custom layers ---
class LearnedPositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, max_len, **kwargs):
        super().__init__(**kwargs)
        self.max_len = max_len
    def build(self, input_shape):
        d_model = input_shape[-1]
        self.pos_emb = self.add_weight(
            name="pos_emb", shape=(self.max_len, d_model),
            initializer="uniform", trainable=True
        )
    def call(self, x):
        return x + self.pos_emb
    def get_config(self):
        config = super().get_config()
        config.update({"max_len": self.max_len})
        return config

class AttentionPooling(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    def build(self, input_shape):
        d = input_shape[-1]
        self.W = self.add_weight(shape=(d,1), initializer="glorot_uniform", trainable=True)
    def call(self, x):
        scores = tf.nn.softmax(tf.squeeze(tf.matmul(x,self.W),axis=-1), axis=1)
        ctx = tf.reduce_sum(x * scores[:,:,None], axis=1)
        return ctx
    def get_config(self):
        return super().get_config()

# --- 2. Load model với custom_objects ---
custom_objs = {
    "LearnedPositionalEmbedding": LearnedPositionalEmbedding,
    "AttentionPooling": AttentionPooling
}

model_path = "/kaggle/working/best_model.keras"  # hoặc .h5
model = load_model(model_path, custom_objects=custom_objs, compile=False)
print("Model loaded!")
# Out:
# Model loaded!

# %%
# ==== Cell: Kiểm tra actions ====
print("✅ Actions list (classes):")
for i, act in enumerate(actions):
    print(f"{i:02d} -> {act}")

# Nếu muốn in số lượng video trên train/val cho từng action
print("\n📊 Train counts:")
for k,v in counts_train.items():
    print(f"{k}: {v} sequences")

print("\n📊 Val counts:")
for k,v in counts_val.items():
    print(f"{k}: {v} sequences")
# Out:
# ✅ Actions list (classes):
# 00 -> Again
# 01 -> BathRoom
# 02 -> Finish
# 03 -> Hello
# 04 -> Help
# 05 -> No
# 06 -> Please
# 07 -> SeeYouLater
# 08 -> ThankYou
# 09 -> Yes
#
# 📊 Train counts:
# Again: 531 sequences
# ThankYou: 411 sequences
# Help: 328 sequences
# Hello: 352 sequences
# SeeYouLater: 512 sequences
# Yes: 536 sequences
# BathRoom: 594 sequences
# Finish: 347 sequences
# Please: 362 sequences
# No: 441 sequences
#
# 📊 Val counts:
# Again: 120 sequences
# Finish: 97 sequences
# No: 95 sequences
# BathRoom: 95 sequences
# Yes: 162 sequences
# Help: 78 sequences
# SeeYouLater: 75 sequences
# Hello: 147 sequences
# Please: 117 sequences
# ThankYou: 103 sequences

# %%
import matplotlib.pyplot as plt

# Sắp xếp theo thứ tự actions
counts_train_sorted = [counts_train[a] for a in actions]
counts_val_sorted   = [counts_val[a] for a in actions]

plt.figure(figsize=(12,5))
plt.bar(actions, counts_train_sorted, alpha=0.7, label="Train")
plt.bar(actions, counts_val_sorted, alpha=0.7, label="Val")
plt.ylabel("Number of sequences")
plt.title("Sequence count per action")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Lấy 1 sequence train bất kỳ
seq = X_train[0]  # shape: (SEQLEN, 134)

# UpperBody: 4 điểm x 2 (x,y)
upper = seq[:, :8].reshape(SEQLEN, 4, 2)

plt.figure(figsize=(6,6))
for i in range(4):
    plt.plot(upper[:,i,0], upper[:,i,1], label=f'Point {i}')
plt.gca().invert_yaxis()  # y xuống dưới giống OpenCV
plt.title(f"Sample UpperBody keypoints (sequence length {SEQLEN})")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
# Lấy 1 batch nhỏ
X_sample = X_val[:8]
y_sample = y_val[:8]

preds = model.predict(X_sample)  # (batch, num_classes)

plt.figure(figsize=(10,5))
for i, p in enumerate(preds):
    top3_idx = p.argsort()[-3:][::-1]
    top3_vals = p[top3_idx]
    top3_labels = [actions[j] for j in top3_idx]
    plt.subplot(2,4,i+1)
    plt.bar(top3_labels, top3_vals, color='skyblue')
    plt.ylim(0,1)
    plt.title(f"Sample {i}")
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

y_pred = model.predict(X_val, batch_size=32)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_val, axis=1)

cm = confusion_matrix(y_true_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(cm, display_labels=actions)
plt.figure(figsize=(10,10))
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix (Validation set)")
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step

# %%
# ==== Cell: Test Video + Overlay (Beautiful UI + Skeleton) ====
import cv2
import numpy as np
from mediapipe import solutions as mp_solutions

SEQLEN = 48
RAW_FEAT_DIM = 134

video_path = "/kaggle/input/againtest/21549.mp4"
out_path   = "/kaggle/working/test_output.mp4"

actions = ["Again","BathRoom","Finish","Hello","Help","No","Please","SeeYouLater","ThankYou","Yes"]

# ------------------------ DRAWING UTILS ------------------------
def draw_skeleton(frame, res):
    mp_drawing = mp_solutions.drawing_utils
    mp_style   = mp_solutions.drawing_styles
    mp_pose    = mp_solutions.pose
    mp_hands   = mp_solutions.hands

    # Pose skeleton (neutral cyan + purple)
    if res.pose_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_style.get_default_pose_landmarks_style(),
        )

    # Hand skeleton (custom neon color)
    if res.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.left_hand_landmarks,
            mp_hands.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(0,255,255), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(0,128,255), thickness=2)
        )

    if res.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.right_hand_landmarks,
            mp_hands.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(255,255,0), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(255,128,0), thickness=2)
        )

def draw_fancy_text(frame, text, pos=(30,50), scale=1.5):
    x, y = pos

    # Background box (transparent)
    overlay = frame.copy()
    cv2.rectangle(overlay, (x-10, y-40), (x + 550, y+20), (0,0,0), -1)
    frame[:] = cv2.addWeighted(overlay, 0.4, frame, 0.6, 0)

    # Shadow effect
    cv2.putText(frame, text, (x+3,y+3), cv2.FONT_HERSHEY_SIMPLEX, scale, (0,0,0), 5, cv2.LINE_AA)

    # Main text in strong yellow
    cv2.putText(frame, text, (x,y), cv2.FONT_HERSHEY_SIMPLEX, scale, (0,255,255), 4, cv2.LINE_AA)

# ------------------------ LOAD VIDEO ------------------------
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Cannot open video:", video_path)
    exit()

fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_vid = cv2.VideoWriter(out_path, fourcc, fps, (w,h))

frames = []
raw_frames = []

# ------------------------ EXTRACT FRAMES + KEYPOINTS ------------------------
with mp_solutions.holistic.Holistic(
    static_image_mode=False,
    model_complexity=1,
    smooth_landmarks=True,
    enable_segmentation=False
) as hol:

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        res = hol.process(frame_rgb)

        kpts = extract_keypoints_from_frame(res)
        frames.append(kpts)
        raw_frames.append((frame.copy(), res))  # save both frame + mediapipe results

cap.release()
frames = np.array(frames, dtype=np.float32)

# ------------------------ CREATE SEQUENCES ------------------------
seqs = []
frame_indices = []
for i in range(0, len(frames)-SEQLEN+1):
    seq = frames[i:i+SEQLEN]
    seq = sequence_upperbody_hand_normalize(seq)
    seqs.append(seq)
    frame_indices.append(i+SEQLEN-1)

if len(seqs) == 0:
    print("Video quá ngắn (< SEQLEN)!")
    exit()

X_test = np.array(seqs, dtype=np.float32)

# ------------------------ MODEL PREDICT ------------------------
preds = model.predict(X_test, batch_size=8)
pred_classes = np.argmax(preds, axis=1)
pred_actions = [actions[i] for i in pred_classes]

frame_action_map = dict(zip(frame_indices, pred_actions))

# ------------------------ DRAW & WRITE OUTPUT ------------------------
for i, (frame, res) in enumerate(raw_frames):

    # 1) Vẽ skeleton
    draw_skeleton(frame, res)

    # 2) Overlay action label
    if i in frame_action_map:
        action = frame_action_map[i]
        draw_fancy_text(frame, f"Action: {action}", (30,80), scale=1.8)

    out_vid.write(frame)

out_vid.release()
print("🎉 Video output saved to:", out_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----- 1. Predict -----
preds = model.predict(X_val, batch_size=32)
y_pred = np.argmax(preds, axis=1)
y_true = np.argmax(y_val, axis=1)

num_classes = len(actions)
class_acc = []

# ----- 2. Compute per-class accuracy -----
for cls in range(num_classes):
    idx = np.where(y_true == cls)[0]
    if len(idx) == 0:
        class_acc.append(0)
    else:
        acc = np.mean(y_pred[idx] == cls)
        class_acc.append(acc)

# ----- 3. Plot -----
plt.figure(figsize=(12,5))
plt.bar(actions, class_acc, color="skyblue")
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("Per-Class Accuracy (Validation Set)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# Print in console too
for a, acc in zip(actions, class_acc):
    print(f"{a:12s}: {acc*100:5.1f}%")
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Again       :  99.2%
# BathRoom    :  98.9%
# Finish      : 100.0%
# Hello       : 100.0%
# Help        : 100.0%
# No          : 100.0%
# Please      : 100.0%
# SeeYouLater : 100.0%
# ThankYou    : 100.0%
# Yes         : 100.0%

# %%
import matplotlib.pyplot as plt

# Lấy biến history
h = history.history

epochs = range(1, len(h["loss"]) + 1)

plt.figure(figsize=(14,5))

# --------- LOSS ----------
plt.subplot(1,2,1)
plt.plot(epochs, h["loss"], label="Train Loss")
plt.plot(epochs, h["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)

# --------- ACCURACY ----------
plt.subplot(1,2,2)
plt.plot(epochs, h["accuracy"], label="Train Acc")
plt.plot(epochs, h["val_accuracy"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %%
# ==== BEAUTIFUL TEST VIDEO CELL (Ultimate UI Edition, Center-only Predict) ====
import cv2
import numpy as np
from mediapipe import solutions as mp_solutions
import math

SEQLEN = 48
RAW_FEAT_DIM = 134

video_path = "/kaggle/input/testthankyou/5211961-uhd_3840_2160_25fps (1).mp4"
out_path   = "/kaggle/working/test_output.mp4"

actions = ["Again","BathRoom","Finish","Hello","Help","No","Please","SeeYouLater","ThankYou","Yes"]

# ------------------------ COLOR UTILS ------------------------
def confidence_to_color(p):
    p = float(p)
    if p < 0.5:
        r = 0
        g = int(255 * (p / 0.5)) 
        b = 255
    else:
        r = 0
        g = 255
        b = int(255 * (1 - (p - 0.5) / 0.5))
    return (b, g, r)

def smooth(prev, new, alpha=0.3):
    if prev is None:
        return new
    return prev * (1 - alpha) + new * alpha

# ------------------------ DRAWING UTILS ------------------------
def draw_skeleton(frame, res):
    mp_drawing = mp_solutions.drawing_utils
    mp_style   = mp_solutions.drawing_styles
    mp_pose    = mp_solutions.pose
    mp_hands   = mp_solutions.hands

    if res.pose_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_style.get_default_pose_landmarks_style(),
        )

    if res.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.left_hand_landmarks,
            mp_hands.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(0,255,255), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(0,128,255), thickness=2)
        )

    if res.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            frame,
            res.right_hand_landmarks,
            mp_hands.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(255,255,0), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(255,128,0), thickness=2)
        )

def draw_label_box(frame, text, conf, pos=(30,80)):
    x,y = pos
    color = confidence_to_color(conf)

    overlay = frame.copy()
    cv2.rectangle(overlay, (x-15, y-55), (x + 650, y+35), (0,0,0), -1)
    frame[:] = cv2.addWeighted(overlay, 0.35, frame, 0.65, 0)

    cv2.putText(frame, text, (x+4,y+4),
                cv2.FONT_HERSHEY_SIMPLEX, 1.8, (0,0,0), 6, cv2.LINE_AA)

    cv2.putText(frame, text, (x,y),
                cv2.FONT_HERSHEY_SIMPLEX, 1.8, color, 5, cv2.LINE_AA)

    bar_x1 = x
    bar_y1 = y + 20
    bar_x2 = x + 500
    bar_y2 = bar_y1 + 20

    cv2.rectangle(frame, (bar_x1, bar_y1), (bar_x2, bar_y2),
                  (40,40,40), -1, cv2.LINE_AA)

    fill_w = int((conf) * 500)
    cv2.rectangle(frame, (bar_x1, bar_y1),
                  (bar_x1 + fill_w, bar_y2),
                  color, -1, cv2.LINE_AA)


# ------------------------ LOAD VIDEO ------------------------
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Cannot open video:", video_path)
    exit()

fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_vid = cv2.VideoWriter(out_path, fourcc, fps, (w,h))

frames = []
raw_frames = []

# ------------------------ EXTRACT FRAMES + KEYPOINTS ------------------------
with mp_solutions.holistic.Holistic(
    static_image_mode=False,
    model_complexity=1,
    smooth_landmarks=True,
    enable_segmentation=False
) as hol:

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        res = hol.process(frame_rgb)

        kpts = extract_keypoints_from_frame(res)
        frames.append(kpts)
        raw_frames.append((frame.copy(), res))

cap.release()
frames = np.array(frames, dtype=np.float32)

# ------------------------ CREATE SEQUENCES (only middle 2/3) ------------------------
seqs = []
frame_indices = []

total_f = len(frames)
mid_start = int(total_f * (1/6))      # bỏ 1/6 đầu
mid_end   = int(total_f * (5/6))      # bỏ 1/6 cuối

for i in range(0, len(frames)-SEQLEN+1):
    mid_frame = i + SEQLEN - 1

    # chỉ giữ frame trong khoảng 2/3 giữa video
    if mid_frame < mid_start or mid_frame > mid_end:
        continue

    seq = frames[i:i+SEQLEN]
    seq = sequence_upperbody_hand_normalize(seq)

    seqs.append(seq)
    frame_indices.append(mid_frame)

if len(seqs) == 0:
    print("Không có sequence nào trong phần giữa video.")
    exit()

X_test = np.array(seqs, dtype=np.float32)

# ------------------------ MODEL PREDICT ------------------------
preds = model.predict(X_test, batch_size=8)
pred_classes = np.argmax(preds, axis=1)
pred_probs   = np.max(preds, axis=1)

frame_action_map = dict(zip(frame_indices, pred_classes))
frame_conf_map   = dict(zip(frame_indices, pred_probs))

smooth_conf = None

# ------------------------ DRAW & WRITE OUTPUT ------------------------
for i, (frame, res) in enumerate(raw_frames):

    draw_skeleton(frame, res)

    if i in frame_action_map:
        cls = frame_action_map[i]
        conf = frame_conf_map[i]
        smooth_conf = smooth(smooth_conf, conf)
        label = f"{actions[cls]}  |  {smooth_conf*100:.1f}%"
        draw_label_box(frame, label, smooth_conf, (30,80))

    out_vid.write(frame)

out_vid.release()
print("🎉 Beautiful video saved to:", out_path)
# Out:
# W0000 00:00:1764330585.909253    8864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.954920    8864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.956850    8864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.958946    8866 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.964272    8863 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.990209    8865 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.992198    8864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764330585.997703    8866 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 🎉 Beautiful video saved to: /kaggle/working/test_output.mp4

# %%
# ==== Cell 1: Plot Accuracy & Loss ====
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(14,5))

# ---- Accuracy ----
ax[0].plot(history.history['accuracy'], label='Train Acc')
ax[0].plot(history.history['val_accuracy'], label='Val Acc')
ax[0].set_title("Training vs Validation Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Accuracy")
ax[0].grid(True)
ax[0].legend()

# ---- Loss ----
ax[1].plot(history.history['loss'], label='Train Loss')
ax[1].plot(history.history['val_loss'], label='Val Loss')
ax[1].set_title("Training vs Validation Loss")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].grid(True)
ax[1].legend()

plt.show()

# %%
# ==== Cell 2: Overfitting Gap ====
import numpy as np

train_loss = np.array(history.history['loss'])
val_loss   = np.array(history.history['val_loss'])

gap = val_loss - train_loss

plt.figure(figsize=(10,5))
plt.plot(gap, label='Val - Train Loss Gap', color='red')
plt.axhline(0, linestyle='--', color='gray')
plt.title("Overfitting Gap per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Gap (>0 = overfit)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# ==== Cell 4: Confusion Matrix ====
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

true_labels = np.argmax(y_val, axis=1)
pred_labels = np.argmax(model.predict(X_val), axis=1)

cm = confusion_matrix(true_labels, pred_labels)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis',
            xticklabels=actions, yticklabels=actions)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
